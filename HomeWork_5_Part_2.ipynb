# %%
import pandas as pd

# %%
import os

# %%
df = pd.read_csv('CSV_2.csv')

# %%
df.head(7)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  7240101  760      SYR82770             82770  30-Sep-20  2020
# 1  7240097  760      SYR82766             82766  30-Sep-20  2020
# 2  7240092  760      SYR82758             82758  30-Sep-20  2020
# 3  7239992  760      SYR82752             82752  30-Sep-20  2020
# 4  7239937  760      SYR82963             82963  30-Sep-20  2020
# 5  7239877  760      SYR82784             82784  30-Sep-20  2020
# 6  7239873  760      SYR82763             82763  30-Sep-20  2020
#
#    time_precision event_type sub_event_type  \
# 0               1    Battles    Armed clash
# 1               1    Battles    Armed clash
# 2               1    Battles    Armed clash
# 3               1    Battles    Armed clash
# 4               1    Battles    Armed clash
# 5               1    Battles    Armed clash
# 6               1    Battles    Armed clash
#
#                                               actor1  ...    location  \
# ...

# %%
ax = df.plot.bar(x = 'event_date', y = 'fatalities')
